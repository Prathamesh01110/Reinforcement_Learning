# %%
import gymnasium as gym

# %%
env = gym.make("CartPole-v1", render_mode="human")

# %%
episodes = 5
for episode in range(1,episodes+1):
    state = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action = env.action_space.sample()
        observation, reward, terminated, truncated, info = env.step(action)
        score += reward
        done = terminated or truncated
    print('Episode:{} Score:{}'.format(episode,score))    
env.close()
# Out:
# Episode:1 Score:21.0
# Episode:2 Score:65.0
# Episode:3 Score:19.0
# Episode:4 Score:10.0
# Episode:5 Score:17.0

# %%
print(env.action_space)
print(env.action_space.sample())
# Out:
# Discrete(2)
# 1

# %%
print(env.observation_space)
print(env.observation_space.sample())
# Out:
# Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)
# [-3.6526368  -0.859481   -0.34740335  0.45624673]

# %%
import os
log_path = os.path.join('Training','Logs')

# %%
log_path
# Out:
# 'Training/Logs'

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
environment_name = "CartPole-v0"
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy',env,verbose=1,tensorboard_log=log_path)
# Out:
# /home/illusion/.local/lib/python3.10/site-packages/gymnasium/envs/registration.py:519: DeprecationWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.deprecation(
# Using cpu device

# %%
PPO??
# Out:
# Init signature:
# PPO(
#     policy: Union[str, type[stable_baselines3.common.policies.ActorCriticPolicy]],
#     env: Union[gymnasium.core.Env, ForwardRef('VecEnv'), str],
#     learning_rate: Union[float, Callable[[float], float]] = 0.0003,
#     n_steps: int = 2048,
#     batch_size: int = 64,
#     n_epochs: int = 10,
#     gamma: float = 0.99,
#     gae_lambda: float = 0.95,
#     clip_range: Union[float, Callable[[float], float]] = 0.2,
#     clip_range_vf: Union[NoneType, float, Callable[[float], float]] = None,
#     normalize_advantage: bool = True,
#     ent_coef: float = 0.0,
#     vf_coef: float = 0.5,
#     max_grad_norm: float = 0.5,
#     use_sde: bool = False,
#     sde_sample_freq: int = -1,
#     rollout_buffer_class: Optional[type[stable_baselines3.common.buffers.RolloutBuffer]] = None,
#     rollout_buffer_kwargs: Optional[dict[str, Any]] = None,
#     target_kl: Optional[float] = None,
#     stats_window_size: int = 100,
#     tensorboard_log: Optional[str] = None,
#     policy_kwargs: Optional[dict[str, Any]] = None,
#     verbose: int = 0,
#     seed: Optional[int] = None,
#     device: Union[torch.device, str] = 'auto',
#     _init_setup_model: bool = True,
# )
# Source:
# class PPO(OnPolicyAlgorithm):
#     """
#     Proximal Policy Optimization algorithm (PPO) (clip version)
#
#     Paper: https://arxiv.org/abs/1707.06347
#     Code: This implementation borrows code from OpenAI Spinning Up (https://github.com/openai/spinningup/)
#     https://github.com/ikostrikov/pytorch-a2c-ppo-acktr-gail and
#     Stable Baselines (PPO2 from https://github.com/hill-a/stable-baselines)
#
#     Introduction to PPO: https://spinningup.openai.com/en/latest/algorithms/ppo.html
#
#     :param policy: The policy model to use (MlpPolicy, CnnPolicy, ...)
#     :param env: The environment to learn from (if registered in Gym, can be str)
#     :param learning_rate: The learning rate, it can be a function
#         of the current progress remaining (from 1 to 0)
#     :param n_steps: The number of steps to run for each environment per update
#         (i.e. rollout buffer size is n_steps * n_envs where n_envs is number of environment copies running in parallel)
#         NOTE: n_steps * n_envs must be greater than 1 (because of the advantage normalization)
#         See https://github.com/pytorch/pytorch/issues/29372
#     :param batch_size: Minibatch size
#     :param n_epochs: Number of epoch when optimizing the surrogate loss
#     :param gamma: Discount factor
#     :param gae_lambda: Factor for trade-off of bias vs variance for Generalized Advantage Estimator
#     :param clip_range: Clipping parameter, it can be a function of the current progress
#         remaining (from 1 to 0).
#     :param clip_range_vf: Clipping parameter for the value function,
#         it can be a function of the current progress remaining (from 1 to 0).
#         This is a parameter specific to the OpenAI implementation. If None is passed (default),
#         no clipping will be done on the value function.
#         IMPORTANT: this clipping depends on the reward scaling.
#     :param normalize_advantage: Whether to normalize or not the advantage
#     :param ent_coef: Entropy coefficient for the loss calculation
#     :param vf_coef: Value function coefficient for the loss calculation
#     :param max_grad_norm: The maximum value for the gradient clipping
#     :param use_sde: Whether to use generalized State Dependent Exploration (gSDE)
#         instead of action noise exploration (default: False)
#     :param sde_sample_freq: Sample a new noise matrix every n steps when using gSDE
#         Default: -1 (only sample at the beginning of the rollout)
#     :param rollout_buffer_class: Rollout buffer class to use. If ``None``, it will be automatically selected.
#     :param rollout_buffer_kwargs: Keyword arguments to pass to the rollout buffer on creation
#     :param target_kl: Limit the KL divergence between updates,
#         because the clipping is not enough to prevent large update
#         see issue #213 (cf https://github.com/hill-a/stable-baselines/issues/213)
#         By default, there is no limit on the kl div.
#     :param stats_window_size: Window size for the rollout logging, specifying the number of episodes to average
#         the reported success rate, mean episode length, and mean reward over
#     :param tensorboard_log: the log location for tensorboard (if None, no logging)
#     :param policy_kwargs: additional arguments to be passed to the policy on creation. See :ref:`ppo_policies`
#     :param verbose: Verbosity level: 0 for no output, 1 for info messages (such as device or wrappers used), 2 for
#         debug messages
#     :param seed: Seed for the pseudo random generators
#     :param device: Device (cpu, cuda, ...) on which the code should be run.
#         Setting it to auto, the code will be run on the GPU if possible.
#     :param _init_setup_model: Whether or not to build the network at the creation of the instance
#     """
#
#     policy_aliases: ClassVar[dict[str, type[BasePolicy]]] = {
#         "MlpPolicy": ActorCriticPolicy,
#         "CnnPolicy": ActorCriticCnnPolicy,
#         "MultiInputPolicy": MultiInputActorCriticPolicy,
#     }
#
#     def __init__(
#         self,
#         policy: Union[str, type[ActorCriticPolicy]],
#         env: Union[GymEnv, str],
#         learning_rate: Union[float, Schedule] = 3e-4,
#         n_steps: int = 2048,
#         batch_size: int = 64,
#         n_epochs: int = 10,
#         gamma: float = 0.99,
#         gae_lambda: float = 0.95,
#         clip_range: Union[float, Schedule] = 0.2,
#         clip_range_vf: Union[None, float, Schedule] = None,
#         normalize_advantage: bool = True,
#         ent_coef: float = 0.0,
#         vf_coef: float = 0.5,
#         max_grad_norm: float = 0.5,
#         use_sde: bool = False,
#         sde_sample_freq: int = -1,
#         rollout_buffer_class: Optional[type[RolloutBuffer]] = None,
#         rollout_buffer_kwargs: Optional[dict[str, Any]] = None,
#         target_kl: Optional[float] = None,
#         stats_window_size: int = 100,
#         tensorboard_log: Optional[str] = None,
#         policy_kwargs: Optional[dict[str, Any]] = None,
#         verbose: int = 0,
#         seed: Optional[int] = None,
#         device: Union[th.device, str] = "auto",
#         _init_setup_model: bool = True,
#     ):
#         super().__init__(
#             policy,
#             env,
#             learning_rate=learning_rate,
#             n_steps=n_steps,
#             gamma=gamma,
#             gae_lambda=gae_lambda,
#             ent_coef=ent_coef,
#             vf_coef=vf_coef,
#             max_grad_norm=max_grad_norm,
#             use_sde=use_sde,
#             sde_sample_freq=sde_sample_freq,
#             rollout_buffer_class=rollout_buffer_class,
#             rollout_buffer_kwargs=rollout_buffer_kwargs,
#             stats_window_size=stats_window_size,
#             tensorboard_log=tensorboard_log,
#             policy_kwargs=policy_kwargs,
#             verbose=verbose,
#             device=device,
#             seed=seed,
#             _init_setup_model=False,
#             supported_action_spaces=(
#                 spaces.Box,
#                 spaces.Discrete,
#                 spaces.MultiDiscrete,
#                 spaces.MultiBinary,
#             ),
#         )
#
#         # Sanity check, otherwise it will lead to noisy gradient and NaN
#         # because of the advantage normalization
#         if normalize_advantage:
#             assert (
#                 batch_size > 1
#             ), "`batch_size` must be greater than 1. See https://github.com/DLR-RM/stable-baselines3/issues/440"
#
#         if self.env is not None:
#             # Check that `n_steps * n_envs > 1` to avoid NaN
#             # when doing advantage normalization
#             buffer_size = self.env.num_envs * self.n_steps
#             assert buffer_size > 1 or (
#                 not normalize_advantage
#             ), f"`n_steps * n_envs` must be greater than 1. Currently n_steps={self.n_steps} and n_envs={self.env.num_envs}"
#             # Check that the rollout buffer size is a multiple of the mini-batch size
#             untruncated_batches = buffer_size // batch_size
#             if buffer_size % batch_size > 0:
#                 warnings.warn(
#                     f"You have specified a mini-batch size of {batch_size},"
#                     f" but because the `RolloutBuffer` is of size `n_steps * n_envs = {buffer_size}`,"
#                     f" after every {untruncated_batches} untruncated mini-batches,"
#                     f" there will be a truncated mini-batch of size {buffer_size % batch_size}\n"
#                     f"We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.\n"
#                     f"Info: (n_steps={self.n_steps} and n_envs={self.env.num_envs})"
#                 )
#         self.batch_size = batch_size
#         self.n_epochs = n_epochs
#         self.clip_range = clip_range
#         self.clip_range_vf = clip_range_vf
#         self.normalize_advantage = normalize_advantage
#         self.target_kl = target_kl
#
#         if _init_setup_model:
#             self._setup_model()
#
#     def _setup_model(self) -> None:
#         super()._setup_model()
#
#         # Initialize schedules for policy/value clipping
#         self.clip_range = get_schedule_fn(self.clip_range)
#         if self.clip_range_vf is not None:
#             if isinstance(self.clip_range_vf, (float, int)):
#                 assert self.clip_range_vf > 0, "`clip_range_vf` must be positive, " "pass `None` to deactivate vf clipping"
#
#             self.clip_range_vf = get_schedule_fn(self.clip_range_vf)
#
#     def train(self) -> None:
#         """
#         Update policy using the currently gathered rollout buffer.
#         """
#         # Switch to train mode (this affects batch norm / dropout)
#         self.policy.set_training_mode(True)
#         # Update optimizer learning rate
#         self._update_learning_rate(self.policy.optimizer)
#         # Compute current clip range
#         clip_range = self.clip_range(self._current_progress_remaining)  # type: ignore[operator]
#         # Optional: clip range for the value function
#         if self.clip_range_vf is not None:
#             clip_range_vf = self.clip_range_vf(self._current_progress_remaining)  # type: ignore[operator]
#
#         entropy_losses = []
#         pg_losses, value_losses = [], []
#         clip_fractions = []
#
#         continue_training = True
#         # train for n_epochs epochs
#         for epoch in range(self.n_epochs):
#             approx_kl_divs = []
#             # Do a complete pass on the rollout buffer
#             for rollout_data in self.rollout_buffer.get(self.batch_size):
#                 actions = rollout_data.actions
#                 if isinstance(self.action_space, spaces.Discrete):
#                     # Convert discrete action from float to long
#                     actions = rollout_data.actions.long().flatten()
#
#                 values, log_prob, entropy = self.policy.evaluate_actions(rollout_data.observations, actions)
#                 values = values.flatten()
#                 # Normalize advantage
#                 advantages = rollout_data.advantages
#                 # Normalization does not make sense if mini batchsize == 1, see GH issue #325
#                 if self.normalize_advantage and len(advantages) > 1:
#                     advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)
#
#                 # ratio between old and new policy, should be one at the first iteration
#                 ratio = th.exp(log_prob - rollout_data.old_log_prob)
#
#                 # clipped surrogate loss
#                 policy_loss_1 = advantages * ratio
#                 policy_loss_2 = advantages * th.clamp(ratio, 1 - clip_range, 1 + clip_range)
#                 policy_loss = -th.min(policy_loss_1, policy_loss_2).mean()
#
#                 # Logging
#                 pg_losses.append(policy_loss.item())
#                 clip_fraction = th.mean((th.abs(ratio - 1) > clip_range).float()).item()
#                 clip_fractions.append(clip_fraction)
#
#                 if self.clip_range_vf is None:
#                     # No clipping
#                     values_pred = values
#                 else:
#                     # Clip the difference between old and new value
#                     # NOTE: this depends on the reward scaling
#                     values_pred = rollout_data.old_values + th.clamp(
#                         values - rollout_data.old_values, -clip_range_vf, clip_range_vf
#                     )
#                 # Value loss using the TD(gae_lambda) target
#                 value_loss = F.mse_loss(rollout_data.returns, values_pred)
#                 value_losses.append(value_loss.item())
#
#                 # Entropy loss favor exploration
#                 if entropy is None:
#                     # Approximate entropy when no analytical form
#                     entropy_loss = -th.mean(-log_prob)
#                 else:
#                     entropy_loss = -th.mean(entropy)
#
#                 entropy_losses.append(entropy_loss.item())
#
#                 loss = policy_loss + self.ent_coef * entropy_loss + self.vf_coef * value_loss
#
#                 # Calculate approximate form of reverse KL Divergence for early stopping
#                 # see issue #417: https://github.com/DLR-RM/stable-baselines3/issues/417
#                 # and discussion in PR #419: https://github.com/DLR-RM/stable-baselines3/pull/419
#                 # and Schulman blog: http://joschu.net/blog/kl-approx.html
#                 with th.no_grad():
#                     log_ratio = log_prob - rollout_data.old_log_prob
#                     approx_kl_div = th.mean((th.exp(log_ratio) - 1) - log_ratio).cpu().numpy()
#                     approx_kl_divs.append(approx_kl_div)
#
#                 if self.target_kl is not None and approx_kl_div > 1.5 * self.target_kl:
#                     continue_training = False
#                     if self.verbose >= 1:
#                         print(f"Early stopping at step {epoch} due to reaching max kl: {approx_kl_div:.2f}")
#                     break
#
#                 # Optimization step
#                 self.policy.optimizer.zero_grad()
#                 loss.backward()
#                 # Clip grad norm
#                 th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
#                 self.policy.optimizer.step()
#
#             self._n_updates += 1
#             if not continue_training:
#                 break
#
#         explained_var = explained_variance(self.rollout_buffer.values.flatten(), self.rollout_buffer.returns.flatten())
#
#         # Logs
#         self.logger.record("train/entropy_loss", np.mean(entropy_losses))
#         self.logger.record("train/policy_gradient_loss", np.mean(pg_losses))
#         self.logger.record("train/value_loss", np.mean(value_losses))
#         self.logger.record("train/approx_kl", np.mean(approx_kl_divs))
#         self.logger.record("train/clip_fraction", np.mean(clip_fractions))
#         self.logger.record("train/loss", loss.item())
#         self.logger.record("train/explained_variance", explained_var)
#         if hasattr(self.policy, "log_std"):
#             self.logger.record("train/std", th.exp(self.policy.log_std).mean().item())
#
#         self.logger.record("train/n_updates", self._n_updates, exclude="tensorboard")
#         self.logger.record("train/clip_range", clip_range)
#         if self.clip_range_vf is not None:
#             self.logger.record("train/clip_range_vf", clip_range_vf)
#
#     def learn(
#         self: SelfPPO,
#         total_timesteps: int,
#         callback: MaybeCallback = None,
#         log_interval: int = 1,
#         tb_log_name: str = "PPO",
#         reset_num_timesteps: bool = True,
#         progress_bar: bool = False,
#     ) -> SelfPPO:
#         return super().learn(
#             total_timesteps=total_timesteps,
#             callback=callback,
#             log_interval=log_interval,
#             tb_log_name=tb_log_name,
#             reset_num_timesteps=reset_num_timesteps,
#             progress_bar=progress_bar,
#         )
# File:           ~/.local/lib/python3.10/site-packages/stable_baselines3/ppo/ppo.py
# Type:           ABCMeta
# Subclasses:

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training/Logs/PPO_11
# -----------------------------
# | time/              |      |
# |    fps             | 2807 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2090        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008980786 |
# |    clip_fraction        | 0.0978      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00449     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.26        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0152     |
# |    value_loss           | 44          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1944        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011225946 |
# |    clip_fraction        | 0.0905      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.662      |
# |    explained_variance   | 0.121       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.3        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.024      |
# |    value_loss           | 29.2        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1879       |
# |    iterations           | 4          |
# |    time_elapsed         | 4          |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00964531 |
# |    clip_fraction        | 0.105      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.632     |
# |    explained_variance   | 0.232      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 19.1       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0209    |
# |    value_loss           | 49.9       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1831        |
# |    iterations           | 5           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007775056 |
# |    clip_fraction        | 0.0452      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.616      |
# |    explained_variance   | 0.262       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.3        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 61.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1802        |
# |    iterations           | 6           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010475645 |
# |    clip_fraction        | 0.0878      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.611      |
# |    explained_variance   | 0.651       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.8        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0149     |
# |    value_loss           | 45.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1784        |
# |    iterations           | 7           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.007070524 |
# |    clip_fraction        | 0.0874      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.581      |
# |    explained_variance   | 0.415       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.5        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0168     |
# |    value_loss           | 75          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1774        |
# |    iterations           | 8           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007876353 |
# |    clip_fraction        | 0.0737      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.57       |
# |    explained_variance   | 0.569       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.5        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 54.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1765        |
# |    iterations           | 9           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010405039 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.578      |
# |    explained_variance   | 0.793       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.97        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 34.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1756         |
# |    iterations           | 10           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0033242814 |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.561       |
# |    explained_variance   | 0.359        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.3         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00496     |
# |    value_loss           | 53.1         |
# ------------------------------------------

# %%
PPO_Path = os.path.join('Training','Saved Models','PPO_Model_Cartpole')

# %%
model.save(PPO_Path)

# %%
env = gym.make(environment_name, render_mode="human")
evaluate_policy(model,env,n_eval_episodes=10,render=True)
# Out:
# /home/illusion/.local/lib/python3.10/site-packages/gymnasium/envs/registration.py:519: DeprecationWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.deprecation(
# /home/illusion/.local/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 env = gym.make(environment_name, render_mode="human")
# ----> 2 evaluate_policy(model,env,n_eval_episodes=10,render=True)
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:131, in evaluate_policy(model, env, n_eval_episodes, deterministic, render, callback, reward_threshold, return_episode_rewards, warn)
#     128     observations = new_observations
#     130     if render:
# --> 131         env.render()
#     133 mean_reward = np.mean(episode_rewards)
#     134 std_reward = np.std(episode_rewards)
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:104, in DummyVecEnv.render(self, mode)
#      97 def render(self, mode: Optional[str] = None) -> Optional[np.ndarray]:
#      98     """
#      99     Gym environment rendering. If there are multiple environments then
#     100     they are tiled together in one image via ``BaseVecEnv.render()``.
#     101
#     102     :param mode: The rendering type.
#     103     """
# --> 104     return super().render(mode=mode)
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:266, in VecEnv.render(self, mode)
#     262 # mode == self.render_mode == "human"
#     263 # In that case, we try to call `self.env.render()` but it might
#     264 # crash for subprocesses
#     265 if self.render_mode == "human":
# --> 266     self.env_method("render")
#     267     return None
#     269 if mode == "rgb_array" or mode == "human":
#     270     # call the render method of the environments
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:130, in DummyVecEnv.env_method(self, method_name, indices, *method_args, **method_kwargs)
#     128 """Call instance methods of vectorized environments."""
#     129 target_envs = self._get_target_envs(indices)
# --> 130 return [env_i.get_wrapper_attr(method_name)(*method_args, **method_kwargs) for env_i in target_envs]
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:130, in <listcomp>(.0)
#     128 """Call instance methods of vectorized environments."""
#     129 target_envs = self._get_target_envs(indices)
# --> 130 return [env_i.get_wrapper_attr(method_name)(*method_args, **method_kwargs) for env_i in target_envs]
#
# File ~/.local/lib/python3.10/site-packages/gymnasium/core.py:337, in Wrapper.render(self)
#     335 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     336     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 337     return self.env.render()
#
# File ~/.local/lib/python3.10/site-packages/gymnasium/wrappers/common.py:409, in OrderEnforcing.render(self)
#     404 if not self._disable_render_order_enforcing and not self._has_reset:
#     405     raise ResetNeeded(
#     406         "Cannot call `env.render()` before calling `env.reset()`, if this is an intended action, "
#     407         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#     408     )
# --> 409 return super().render()
#
# File ~/.local/lib/python3.10/site-packages/gymnasium/core.py:337, in Wrapper.render(self)
#     335 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     336     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 337     return self.env.render()
#
# File ~/.local/lib/python3.10/site-packages/gymnasium/wrappers/common.py:303, in PassiveEnvChecker.render(self)
#     301     return env_render_passive_checker(self.env)
#     302 else:
# --> 303     return self.env.render()
#
# File ~/.local/lib/python3.10/site-packages/gymnasium/envs/classic_control/cartpole.py:337, in CartPoleEnv.render(self)
#     335 if self.render_mode == "human":
#     336     pygame.event.pump()
# --> 337     self.clock.tick(self.metadata["render_fps"])
#     338     pygame.display.flip()
#     340 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:

# %%
env.close()

# %%
obs, _ = env.reset()
action, _ = model.predict(obs)

action
# Out:
# array(1)

# %%
# Fix for the rendering issue
env = gym.make(environment_name, render_mode="human")  # Reinitialize the environment
episodes = 5
for episode in range(1, episodes + 1):
    obs, _ = env.reset()  # Reset the environment
    done = False
    score = 0

    while not done:
        try:
            env.render()  # Render the environment
        except Exception as e:
            print(f"Rendering error: {e}")
            break  # Exit the loop if rendering fails

        action, _ = model.predict(obs)  # Predict action using the model
        obs, reward, terminated, truncated, info = env.step(action)
        score += reward
        done = terminated or truncated

    print(f'Episode: {episode} Score: {score}')
env.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Fix for the rendering issue
# ----> 2 env = gym.make(environment_name, render_mode="human")  # Reinitialize the environment
#       3 episodes = 5
#       4 for episode in range(1, episodes + 1):
#
# NameError: name 'gym' is not defined

# %%
env = gym.make("CartPole-v1", render_mode="human")  # recreate environment
obs, info = env.reset()  # now works again
print(obs)
# Out:
# [-0.02617642  0.02392025  0.04807609 -0.02237277]

# %%
action, _ = model.predict(obs)

# %%
env.action_space.sample()
# Out:
# np.int64(0)

# %%
env.step(action)
# Out:
# (array([-9.3199866e-04,  8.0194622e-01,  1.2980967e-02, -1.1391455e+00],
#        dtype=float32),
#  1.0,
#  False,
#  False,
#  {})

# %%
env.close()  # close the environment

# %%
training_log_path = os.path.join(log_path, 'PPO_11')

# %%
training_log_path
# Out:
# 'Training/Logs/PPO_11'

# %%
# !tensorboard --logdir={training_log_path}
# Out:
# TensorFlow installation not found - running with reduced feature set.
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.19.0 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold
import os
env = gym.make("CartPole-v0")
# Out:
# /home/illusion/.local/lib/python3.10/site-packages/gymnasium/envs/registration.py:519: DeprecationWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.deprecation(

# %%
save_path = os.path.join('Training', 'Saved Models')

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=200, verbose=1)
eval_callback = EvalCallback(env,
callback_on_new_best=stop_callback,
    eval_freq=10000,
    best_model_save_path=save_path,
    verbose=1
)

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training/Logs/PPO_12
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.5     |
# |    ep_rew_mean     | 23.5     |
# | time/              |          |
# |    fps             | 2820     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.5        |
# |    ep_rew_mean          | 28.5        |
# | time/                   |             |
# |    fps                  | 1961        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008307628 |
# |    clip_fraction        | 0.0833      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | -0.00722    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.22        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 54.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.6        |
# |    ep_rew_mean          | 36.6        |
# | time/                   |             |
# |    fps                  | 1801        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.007992678 |
# |    clip_fraction        | 0.0543      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.666      |
# |    explained_variance   | 0.0751      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.2        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0168     |
# |    value_loss           | 37.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 1714        |
# |    iterations           | 4           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009590745 |
# |    clip_fraction        | 0.0892      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.629      |
# |    explained_variance   | 0.19        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.4        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0193     |
# |    value_loss           | 59.3        |
# -----------------------------------------
# /home/illusion/.local/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000, episode_reward=176.40 +/- 23.00
# Episode length: 176.40 +/- 23.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 176         |
# |    mean_reward          | 176         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.006908298 |
# |    clip_fraction        | 0.0447      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.62       |
# |    explained_variance   | 0.332       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.2        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 54.3        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 64.1     |
# |    ep_rew_mean     | 64.1     |
# | time/              |          |
# |    fps             | 1616     |
# |    iterations      | 5        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 10240    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 78.5         |
# |    ep_rew_mean          | 78.5         |
# | time/                   |              |
# |    fps                  | 1608         |
# |    iterations           | 6            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0067422027 |
# |    clip_fraction        | 0.0642       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.594       |
# |    explained_variance   | 0.494        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.4         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0137      |
# |    value_loss           | 61.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.5        |
# |    ep_rew_mean          | 95.5        |
# | time/                   |             |
# |    fps                  | 1598        |
# |    iterations           | 7           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.006836976 |
# |    clip_fraction        | 0.0696      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.598      |
# |    explained_variance   | 0.672       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.4        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 45.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 110         |
# |    ep_rew_mean          | 110         |
# | time/                   |             |
# |    fps                  | 1587        |
# |    iterations           | 8           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009182551 |
# |    clip_fraction        | 0.0876      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.58       |
# |    explained_variance   | 0.545       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.21        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 47.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 127         |
# |    ep_rew_mean          | 127         |
# | time/                   |             |
# |    fps                  | 1583        |
# |    iterations           | 9           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.005477451 |
# |    clip_fraction        | 0.0364      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.56       |
# |    explained_variance   | 0.458       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.72        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00663    |
# |    value_loss           | 57.1        |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    total_timesteps      | 20000        |
# | train/                  |              |
# |    approx_kl            | 0.0070501845 |
# |    clip_fraction        | 0.0873       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.571       |
# |    explained_variance   | 0.854        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.14         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0128      |
# |    value_loss           | 18.1         |
# ------------------------------------------
# New best mean reward!
# Stopping training because the mean reward 200.00  is above the threshold 200

# %%
net_arch = [dict(pi=[128,128,128,128],vf=[128,128,128,128])]

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path , policy_kwargs=dict(net_arch=net_arch))
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training/Logs/PPO_13
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.5     |
# |    ep_rew_mean     | 22.5     |
# | time/              |          |
# |    fps             | 2342     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.8        |
# |    ep_rew_mean          | 28.8        |
# | time/                   |             |
# |    fps                  | 1574        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015752481 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.68       |
# |    explained_variance   | -0.000666   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.63        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0321     |
# |    value_loss           | 19.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.6        |
# |    ep_rew_mean          | 41.6        |
# | time/                   |             |
# |    fps                  | 1380        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016095873 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.642      |
# |    explained_variance   | 0.456       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.7        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0335     |
# |    value_loss           | 27          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 57.4       |
# |    ep_rew_mean          | 57.4       |
# | time/                   |            |
# |    fps                  | 1300       |
# |    iterations           | 4          |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01187899 |
# |    clip_fraction        | 0.177      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.606     |
# |    explained_variance   | 0.441      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 21.7       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0301    |
# |    value_loss           | 46         |
# ----------------------------------------
# /home/illusion/.local/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.010130774 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.577      |
# |    explained_variance   | 0.465       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18          |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0185     |
# |    value_loss           | 52.5        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.1     |
# |    ep_rew_mean     | 74.1     |
# | time/              |          |
# |    fps             | 1187     |
# |    iterations      | 5        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 10240    |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 91.8       |
# |    ep_rew_mean          | 91.8       |
# | time/                   |            |
# |    fps                  | 1160       |
# |    iterations           | 6          |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.01062179 |
# |    clip_fraction        | 0.0984     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.547     |
# |    explained_variance   | 0.534      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.41       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.00909   |
# |    value_loss           | 24.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 108         |
# |    ep_rew_mean          | 108         |
# | time/                   |             |
# |    fps                  | 1145        |
# |    iterations           | 7           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.006299787 |
# |    clip_fraction        | 0.0807      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.547      |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.65        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 12          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 126         |
# |    ep_rew_mean          | 126         |
# | time/                   |             |
# |    fps                  | 1133        |
# |    iterations           | 8           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006410604 |
# |    clip_fraction        | 0.0618      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.551      |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.62        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00612    |
# |    value_loss           | 7.73        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 141         |
# |    ep_rew_mean          | 141         |
# | time/                   |             |
# |    fps                  | 1129        |
# |    iterations           | 9           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009150981 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.533      |
# |    explained_variance   | 0.924       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.07        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 4.84        |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    total_timesteps      | 20000        |
# | train/                  |              |
# |    approx_kl            | 0.0049214726 |
# |    clip_fraction        | 0.0596       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.509       |
# |    explained_variance   | 0.133        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.88         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00592     |
# |    value_loss           | 24.2         |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 156      |
# |    ep_rew_mean     | 156      |
# | time/              |          |
# |    fps             | 1095     |
# |    iterations      | 10       |
# |    time_elapsed    | 18       |
# |    total_timesteps | 20480    |
# ---------------------------------

# %%
from stable_baselines3 import DQN

# %%
model  = DQN('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training/Logs/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28       |
# |    ep_rew_mean      | 28       |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 3827     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 112      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.498    |
# |    n_updates        | 2        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32       |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 2573     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 256      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.407    |
# |    n_updates        | 38       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.9     |
# |    ep_rew_mean      | 30.9     |
# |    exploration_rate | 0.824    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 2243     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 371      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.333    |
# |    n_updates        | 67       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.3     |
# |    ep_rew_mean      | 31.3     |
# |    exploration_rate | 0.762    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 2262     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 501      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.255    |
# |    n_updates        | 100      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.5     |
# |    ep_rew_mean      | 32.5     |
# |    exploration_rate | 0.692    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 2252     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 649      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.172    |
# |    n_updates        | 137      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.6     |
# |    ep_rew_mean      | 32.6     |
# |    exploration_rate | 0.629    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 2200     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 782      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.123    |
# |    n_updates        | 170      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.2     |
# |    ep_rew_mean      | 33.2     |
# |    exploration_rate | 0.558    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 2119     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 931      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0721   |
# |    n_updates        | 207      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.9     |
# |    ep_rew_mean      | 32.9     |
# |    exploration_rate | 0.499    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 2117     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1054     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0541   |
# |    n_updates        | 238      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.8     |
# |    ep_rew_mean      | 32.8     |
# |    exploration_rate | 0.439    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 2129     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1181     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0308   |
# |    n_updates        | 270      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.8     |
# |    ep_rew_mean      | 32.8     |
# |    exploration_rate | 0.376    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 2091     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1313     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0129   |
# |    n_updates        | 303      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.2     |
# |    ep_rew_mean      | 32.2     |
# |    exploration_rate | 0.327    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 2086     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1417     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00839  |
# |    n_updates        | 329      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.3     |
# |    ep_rew_mean      | 31.3     |
# |    exploration_rate | 0.286    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 2081     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1504     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00692  |
# |    n_updates        | 350      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.3     |
# |    ep_rew_mean      | 30.3     |
# |    exploration_rate | 0.251    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 2069     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1577     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00934  |
# |    n_updates        | 369      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.2     |
# |    ep_rew_mean      | 29.2     |
# |    exploration_rate | 0.223    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 2060     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1636     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00638  |
# |    n_updates        | 383      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.2     |
# |    ep_rew_mean      | 28.2     |
# |    exploration_rate | 0.196    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 2053     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1692     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00932  |
# |    n_updates        | 397      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.6     |
# |    ep_rew_mean      | 27.6     |
# |    exploration_rate | 0.161    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 2041     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1767     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00621  |
# |    n_updates        | 416      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.7     |
# |    ep_rew_mean      | 26.7     |
# |    exploration_rate | 0.138    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 2031     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1814     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00707  |
# |    n_updates        | 428      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.8     |
# |    ep_rew_mean      | 25.8     |
# |    exploration_rate | 0.117    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 2026     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1859     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00924  |
# |    n_updates        | 439      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | 25       |
# |    exploration_rate | 0.0966   |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 2016     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1902     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00748  |
# |    n_updates        | 450      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.3     |
# |    ep_rew_mean      | 24.3     |
# |    exploration_rate | 0.0776   |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 2010     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1942     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00781  |
# |    n_updates        | 460      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.5     |
# |    ep_rew_mean      | 23.5     |
# |    exploration_rate | 0.0609   |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 2004     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1977     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00717  |
# |    n_updates        | 469      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 2000     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2016     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00883  |
# |    n_updates        | 478      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1991     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2054     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.006    |
# |    n_updates        | 488      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.8     |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1984     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2093     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0145   |
# |    n_updates        | 498      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1977     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2137     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00471  |
# |    n_updates        | 509      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1969     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2177     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00723  |
# |    n_updates        | 519      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.6     |
# |    ep_rew_mean      | 19.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1959     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2216     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0133   |
# |    n_updates        | 528      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.9     |
# |    ep_rew_mean      | 18.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1949     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2257     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00643  |
# |    n_updates        | 539      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18       |
# |    ep_rew_mean      | 18       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1942     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2299     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0033   |
# |    n_updates        | 549      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.9     |
# |    ep_rew_mean      | 16.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1941     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2335     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00367  |
# |    n_updates        | 558      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.9     |
# |    ep_rew_mean      | 15.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1936     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2377     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00777  |
# |    n_updates        | 569      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1935     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2419     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00319  |
# |    n_updates        | 579      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1924     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2466     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00656  |
# |    n_updates        | 591      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 13.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1913     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2509     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00466  |
# |    n_updates        | 602      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.4     |
# |    ep_rew_mean      | 12.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1913     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2550     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00272  |
# |    n_updates        | 612      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 11.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1908     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2591     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00337  |
# |    n_updates        | 622      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 11.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1904     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2629     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00448  |
# |    n_updates        | 632      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 10.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1902     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2670     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00276  |
# |    n_updates        | 642      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1899     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2710     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00273  |
# |    n_updates        | 652      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1898     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2748     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00161  |
# |    n_updates        | 661      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1895     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2784     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00229  |
# |    n_updates        | 670      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1891     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2823     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00219  |
# |    n_updates        | 680      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10       |
# |    ep_rew_mean      | 10       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1888     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2859     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0019   |
# |    n_updates        | 689      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.95     |
# |    ep_rew_mean      | 9.95     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1885     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2897     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00238  |
# |    n_updates        | 699      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.92     |
# |    ep_rew_mean      | 9.92     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1883     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2934     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00135  |
# |    n_updates        | 708      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.96     |
# |    ep_rew_mean      | 9.96     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1881     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2973     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00145  |
# |    n_updates        | 718      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.96     |
# |    ep_rew_mean      | 9.96     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1879     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3012     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00201  |
# |    n_updates        | 727      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10       |
# |    ep_rew_mean      | 10       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1878     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3055     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00141  |
# |    n_updates        | 738      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.99     |
# |    ep_rew_mean      | 9.99     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1877     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3092     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00187  |
# |    n_updates        | 747      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.96     |
# |    ep_rew_mean      | 9.96     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1873     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3133     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00105  |
# |    n_updates        | 758      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.95     |
# |    ep_rew_mean      | 9.95     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1869     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3172     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0011   |
# |    n_updates        | 767      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.94     |
# |    ep_rew_mean      | 9.94     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1864     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3210     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000497 |
# |    n_updates        | 777      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.9      |
# |    ep_rew_mean      | 9.9      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1863     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3247     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000842 |
# |    n_updates        | 786      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.87     |
# |    ep_rew_mean      | 9.87     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1860     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3286     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00144  |
# |    n_updates        | 796      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.89     |
# |    ep_rew_mean      | 9.89     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1858     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3324     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000957 |
# |    n_updates        | 805      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.85     |
# |    ep_rew_mean      | 9.85     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1853     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3362     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00201  |
# |    n_updates        | 815      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.82     |
# |    ep_rew_mean      | 9.82     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1851     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3401     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00101  |
# |    n_updates        | 825      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.76     |
# |    ep_rew_mean      | 9.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1849     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3442     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00241  |
# |    n_updates        | 835      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.75     |
# |    ep_rew_mean      | 9.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1849     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3484     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00074  |
# |    n_updates        | 845      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.74     |
# |    ep_rew_mean      | 9.74     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1847     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3524     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00139  |
# |    n_updates        | 855      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.74     |
# |    ep_rew_mean      | 9.74     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1843     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3565     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000874 |
# |    n_updates        | 866      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.74     |
# |    ep_rew_mean      | 9.74     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1843     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3603     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00093  |
# |    n_updates        | 875      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.75     |
# |    ep_rew_mean      | 9.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1841     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3645     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0018   |
# |    n_updates        | 886      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.7      |
# |    ep_rew_mean      | 9.7      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 1841     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3680     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00131  |
# |    n_updates        | 894      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.7      |
# |    ep_rew_mean      | 9.7      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1839     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3718     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000709 |
# |    n_updates        | 904      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.77     |
# |    ep_rew_mean      | 9.77     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1837     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3761     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00128  |
# |    n_updates        | 915      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.77     |
# |    ep_rew_mean      | 9.77     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 1836     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3800     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000951 |
# |    n_updates        | 924      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.81     |
# |    ep_rew_mean      | 9.81     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 1835     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3840     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000808 |
# |    n_updates        | 934      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.82     |
# |    ep_rew_mean      | 9.82     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 1834     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3879     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00188  |
# |    n_updates        | 944      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.85     |
# |    ep_rew_mean      | 9.85     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1832     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3919     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00159  |
# |    n_updates        | 954      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.83     |
# |    ep_rew_mean      | 9.83     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 1830     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3956     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000954 |
# |    n_updates        | 963      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.83     |
# |    ep_rew_mean      | 9.83     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 1828     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3995     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000686 |
# |    n_updates        | 973      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.81     |
# |    ep_rew_mean      | 9.81     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 1828     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4036     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00104  |
# |    n_updates        | 983      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.8      |
# |    ep_rew_mean      | 9.8      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 1825     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4072     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000668 |
# |    n_updates        | 992      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.75     |
# |    ep_rew_mean      | 9.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1821     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4108     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00132  |
# |    n_updates        | 1001     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.72     |
# |    ep_rew_mean      | 9.72     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 1819     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4144     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00102  |
# |    n_updates        | 1010     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.73     |
# |    ep_rew_mean      | 9.73     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 1816     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4183     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000832 |
# |    n_updates        | 1020     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.73     |
# |    ep_rew_mean      | 9.73     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 1813     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4220     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000973 |
# |    n_updates        | 1029     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.73     |
# |    ep_rew_mean      | 9.73     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 1811     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4259     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00125  |
# |    n_updates        | 1039     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.75     |
# |    ep_rew_mean      | 9.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1810     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4299     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00093  |
# |    n_updates        | 1049     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.76     |
# |    ep_rew_mean      | 9.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 1809     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4338     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00256  |
# |    n_updates        | 1059     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.77     |
# |    ep_rew_mean      | 9.77     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 1808     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4378     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00156  |
# |    n_updates        | 1069     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.77     |
# |    ep_rew_mean      | 9.77     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 1805     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4419     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000614 |
# |    n_updates        | 1079     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.73     |
# |    ep_rew_mean      | 9.73     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 1803     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4457     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00118  |
# |    n_updates        | 1089     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.7      |
# |    ep_rew_mean      | 9.7      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1801     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4494     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000855 |
# |    n_updates        | 1098     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.65     |
# |    ep_rew_mean      | 9.65     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 1801     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4530     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000497 |
# |    n_updates        | 1107     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.65     |
# |    ep_rew_mean      | 9.65     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 1799     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4568     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000708 |
# |    n_updates        | 1116     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.66     |
# |    ep_rew_mean      | 9.66     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 1797     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4611     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000695 |
# |    n_updates        | 1127     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.69     |
# |    ep_rew_mean      | 9.69     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 1797     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4649     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00101  |
# |    n_updates        | 1137     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.73     |
# |    ep_rew_mean      | 9.73     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1796     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4691     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000819 |
# |    n_updates        | 1147     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.69     |
# |    ep_rew_mean      | 9.69     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 1796     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4730     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000483 |
# |    n_updates        | 1157     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.7      |
# |    ep_rew_mean      | 9.7      |
# |    exploration_rate | 0.05     |
# ...
# |    time_elapsed     | 11       |
# |    total_timesteps  | 18060    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0161   |
# |    n_updates        | 4489     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 10.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1736     |
# |    fps              | 1617     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 18098    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0121   |
# |    n_updates        | 4499     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 10.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1740     |
# |    fps              | 1616     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 18136    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0102   |
# |    n_updates        | 4508     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 10.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1744     |
# |    fps              | 1616     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 18172    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.023    |
# |    n_updates        | 4517     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 10.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1748     |
# |    fps              | 1616     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 18212    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0173   |
# |    n_updates        | 4527     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 10.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1752     |
# |    fps              | 1615     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 18247    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0215   |
# |    n_updates        | 4536     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1756     |
# |    fps              | 1614     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 18285    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00577  |
# |    n_updates        | 4546     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1760     |
# |    fps              | 1614     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 18318    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0108   |
# |    n_updates        | 4554     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1764     |
# |    fps              | 1613     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 18357    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00868  |
# |    n_updates        | 4564     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.94     |
# |    ep_rew_mean      | 9.94     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1768     |
# |    fps              | 1613     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 18393    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00635  |
# |    n_updates        | 4573     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.59     |
# |    ep_rew_mean      | 9.59     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1772     |
# |    fps              | 1613     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 18432    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00442  |
# |    n_updates        | 4582     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.81     |
# |    ep_rew_mean      | 9.81     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1776     |
# |    fps              | 1613     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 18492    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00543  |
# |    n_updates        | 4597     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.88     |
# |    ep_rew_mean      | 9.88     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1780     |
# |    fps              | 1613     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 18538    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0156   |
# |    n_updates        | 4609     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.87     |
# |    ep_rew_mean      | 9.87     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1784     |
# |    fps              | 1612     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 18574    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0137   |
# |    n_updates        | 4618     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.86     |
# |    ep_rew_mean      | 9.86     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1788     |
# |    fps              | 1612     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 18613    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0063   |
# |    n_updates        | 4628     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.88     |
# |    ep_rew_mean      | 9.88     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1792     |
# |    fps              | 1612     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 18653    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0133   |
# |    n_updates        | 4638     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1796     |
# |    fps              | 1612     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 18729    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0178   |
# |    n_updates        | 4657     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 10.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1800     |
# |    fps              | 1613     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 18835    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00634  |
# |    n_updates        | 4683     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 11.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1804     |
# |    fps              | 1614     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 18911    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0101   |
# |    n_updates        | 4702     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1808     |
# |    fps              | 1615     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 19016    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00643  |
# |    n_updates        | 4728     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1812     |
# |    fps              | 1615     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 19053    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00783  |
# |    n_updates        | 4738     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 11.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1816     |
# |    fps              | 1614     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 19095    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0191   |
# |    n_updates        | 4748     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 12.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1820     |
# |    fps              | 1613     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 19152    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0214   |
# |    n_updates        | 4762     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 12.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1824     |
# |    fps              | 1613     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 19191    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0156   |
# |    n_updates        | 4772     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.6     |
# |    ep_rew_mean      | 12.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1828     |
# |    fps              | 1614     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 19284    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0132   |
# |    n_updates        | 4795     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 13.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1832     |
# |    fps              | 1615     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 19404    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00821  |
# |    n_updates        | 4825     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1836     |
# |    fps              | 1614     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 19509    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00585  |
# |    n_updates        | 4852     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1840     |
# |    fps              | 1614     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 19623    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0389   |
# |    n_updates        | 4880     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.9     |
# |    ep_rew_mean      | 15.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1844     |
# |    fps              | 1612     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 19760    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00376  |
# |    n_updates        | 4914     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.4     |
# |    ep_rew_mean      | 16.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1848     |
# |    fps              | 1613     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 19848    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0121   |
# |    n_updates        | 4936     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.2     |
# |    ep_rew_mean      | 17.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1852     |
# |    fps              | 1613     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 19968    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.018    |
# |    n_updates        | 4966     |
# ----------------------------------
